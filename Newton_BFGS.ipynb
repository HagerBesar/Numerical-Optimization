# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Newton's Method Optimization
# ### Single Variable
# - Implement the <b>Gradient decent and Newton's method</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐−𝟏𝟓𝒙+𝟏$,
# - Draw the functions and check out the minimum.
# - Draw the 1st derivative of the function and check out the root.
# - Draw 2nd derivative of the function and check out the sign at the minimum.
# - The stop condition is grad < epsilon.
# - Try different epsilons and initial conditions.
# - Compare the results with Gradient descent.
# ##### The function should return the solution and the gradient.

# %% [markdown]
# ##### Notes:
# - You will need to pass the expression of the function, first, and second derivatives to the optimizer.
# - You can use lambda expression to construct the function, first, and second derivatives.

# %%
f = lambda x: x**2 - 15*x +1
Df = lambda x: 2*x -15
DDf = lambda x: 2

# %%
X = np.arange(-50,60)

# %%
X = np.arange(-50,60)
y = f(X)
Dy = Df(X)
DDy = np.array([DDf(x) for x in X])

# %%
plt.plot(X,y)
plt.style.use('seaborn')
plt.show()

plt.plot(X,Dy)
plt.style.use('seaborn')
plt.show()

plt.plot(X,DDy)
plt.style.use('seaborn')
plt.show()

# %%
def Gradient_D(X ,y ,f, rate ,max_it):
    theta_0 = 40
    loss=[]
    Theta_0=[]
    Theta_1=[]
    H =[]
    
    for i in range(max_it):
        print(f"\n****************** Iteration {i} ********************")
        Theta_0.append(theta_0)
        Theta_1.append(theta_1) #𝒙𝟐−𝟏𝟓𝒙+𝟏 => 2x-15
        h_x = theta_0 * X
        H.append(h_x)
        print("h(x):" ,h_x)
        err=(h_x - y)
        m_2 = 2*len(X)
        j = 1/m_2 * sum(err**2)
        loss.append(j)
        print("\nError Vector:\n" , err)
        print("\nj = " ,j)
        d_theta_0=  1/len(X) * sum((err))
        d_theta_1= 1/len(X) * sum((err)* X)
        G_V= np.array([[d_theta_0],
                       [d_theta_1]])
        print("\nGradient Vector :\n",G_V)
        G_norm = np.linalg.norm(G_V)
        print("\nGradient Vector Norm :\n",G_norm)
        
        
        
        
        if i >2 and abs(loss[-1] -loss[-2]) <= 0.1:
                break
    
        if G_norm <= 0.1 :
            break
            
        theta_0 = theta_0 - rate * f(x)
        theta_1 = theta_1 - rate * d_theta_1 
        

        print("\ntheta_0_new : ",theta_0)
        print("theta_1_new : ",theta_1)
        
    # ****************** Training Report ********************
    print("\n****************** Training Report ********************")
    print(f"\nGradient Descent converged after {i+1} iterations")
    print("\ntheta_0_Opt : " ,theta_0)
    print("theta_1_Opt : " ,theta_1)
    print("\nError Vector: ",err)
    print("\ncost : ",j)
    print("\nh(x) = y_predict: \n" ,h_x)
    print("\ny_actual:\n" , y)
    print()    
        
    return Theta_0, Theta_1 , H ,  loss

# %%
def Gradient(x0, max_it,alpha , df ):
    x=x0
     
    for i in range(max_it):
        print(f"\n****************** Iteration {i} ********************")
        x = x -  (df(x) *alpha)
        print(x)
        grad = np.abs(df(x))
        print(grad)
        if grad < 0.1:
            break
        
     
    
    return x , grad ,i

# %%
x_min , grad , i = Gradient(40, 400, 0.01 ,Df)
# Out:
# ****************** Iteration 0 ********************
# 39.35
# 63.7
#
# ****************** Iteration 1 ********************
# 38.713
# 62.426
#
# ****************** Iteration 2 ********************
# 38.08874
# 61.17748
#
# ****************** Iteration 3 ********************
# 37.4769652
# 59.953930400000004
#
# ****************** Iteration 4 ********************
# 36.877425896000005
# 58.75485179200001
#
# ****************** Iteration 5 ********************
# 36.28987737808001
# 57.579754756160014
#
# ****************** Iteration 6 ********************
# 35.71407983051841
# 56.428159661036815
#
# ****************** Iteration 7 ********************
# 35.14979823390804
# 55.29959646781607
#
# ****************** Iteration 8 ********************
# 34.596802269229876
# 54.19360453845975
#
# ****************** Iteration 9 ********************
# 34.05486622384528
# 53.10973244769056
#
# ****************** Iteration 10 ********************
# 33.52376889936838
# 52.047537798736755
#
# ****************** Iteration 11 ********************
# 33.00329352138101
# 51.00658704276202
#
# ****************** Iteration 12 ********************
# 32.49322765095339
# 49.98645530190679
#
# ****************** Iteration 13 ********************
# 31.993363097934324
# 48.98672619586865
#
# ****************** Iteration 14 ********************
# 31.503495835975638
# 48.006991671951276
#
# ****************** Iteration 15 ********************
# 31.023425919256127
# 47.046851838512254
#
# ****************** Iteration 16 ********************
# 30.552957400871005
# 46.10591480174201
#
# ****************** Iteration 17 ********************
# 30.091898252853586
# 45.18379650570717
#
# ****************** Iteration 18 ********************
# 29.640060287796516
# 44.28012057559303
#
# ****************** Iteration 19 ********************
# 29.197259082040585
# 43.39451816408117
#
# ****************** Iteration 20 ********************
# 28.763313900399773
# 42.526627800799545
#
# ****************** Iteration 21 ********************
# 28.338047622391777
# 41.67609524478355
#
# ****************** Iteration 22 ********************
# 27.921286669943942
# 40.842573339887885
#
# ****************** Iteration 23 ********************
# 27.512860936545064
# 40.02572187309013
#
# ****************** Iteration 24 ********************
# 27.112603717814164
# 39.22520743562833
#
# ****************** Iteration 25 ********************
# 26.72035164345788
# 38.44070328691576
#
# ****************** Iteration 26 ********************
# 26.335944610588722
# 37.671889221177445
#
# ****************** Iteration 27 ********************
# 25.95922571837695
# 36.9184514367539
#
# ****************** Iteration 28 ********************
# 25.59004120400941
# 36.18008240801882
#
# ****************** Iteration 29 ********************
# 25.228240379929222
# 35.456480759858444
#
# ****************** Iteration 30 ********************
# 24.873675572330637
# 34.74735114466127
#
# ****************** Iteration 31 ********************
# 24.526202060884025
# 34.05240412176805
#
# ****************** Iteration 32 ********************
# 24.185678019666344
# 33.37135603933269
#
# ****************** Iteration 33 ********************
# 23.851964459273017
# 32.70392891854603
#
# ****************** Iteration 34 ********************
# 23.524925170087556
# 32.04985034017511
#
# ****************** Iteration 35 ********************
# 23.204426666685805
# 31.40885333337161
#
# ****************** Iteration 36 ********************
# 22.89033813335209
# 30.780676266704177
#
# ****************** Iteration 37 ********************
# 22.582531370685047
# 30.165062741370093
#
# ****************** Iteration 38 ********************
# 22.280880743271346
# 29.561761486542693
#
# ****************** Iteration 39 ********************
# 21.98526312840592
# 28.970526256811837
#
# ****************** Iteration 40 ********************
# 21.6955578658378
# 28.391115731675598
#
# ****************** Iteration 41 ********************
# 21.411646708521044
# 27.823293417042088
#
# ****************** Iteration 42 ********************
# 21.133413774350622
# 27.266827548701244
#
# ****************** Iteration 43 ********************
# 20.860745498863608
# 26.721490997727216
#
# ****************** Iteration 44 ********************
# 20.593530588886335
# 26.18706117777267
#
# ****************** Iteration 45 ********************
# 20.331659977108608
# 25.663319954217215
#
# ****************** Iteration 46 ********************
# 20.075026777566435
# 25.15005355513287
#
# ****************** Iteration 47 ********************
# 19.823526242015106
# 24.647052484030212
#
# ****************** Iteration 48 ********************
# 19.577055717174805
# 24.15411143434961
#
# ****************** Iteration 49 ********************
# 19.33551460283131
# 23.67102920566262
#
# ****************** Iteration 50 ********************
# 19.098804310774685
# 23.19760862154937
#
# ****************** Iteration 51 ********************
# 18.866828224559193
# 22.733656449118385
#
# ****************** Iteration 52 ********************
# 18.639491660068007
# 22.278983320136014
#
# ****************** Iteration 53 ********************
# 18.416701826866646
# 21.833403653733292
#
# ****************** Iteration 54 ********************
# 18.198367790329314
# 21.39673558065863
#
# ****************** Iteration 55 ********************
# 17.984400434522726
# 20.968800869045452
#
# ****************** Iteration 56 ********************
# 17.77471242583227
# 20.54942485166454
#
# ****************** Iteration 57 ********************
# 17.569218177315623
# 20.138436354631246
#
# ****************** Iteration 58 ********************
# 17.36783381376931
# 19.735667627538618
#
# ****************** Iteration 59 ********************
# 17.170477137493922
# 19.340954274987844
#
# ****************** Iteration 60 ********************
# 16.977067594744042
# 18.954135189488085
#
# ****************** Iteration 61 ********************
# 16.78752624284916
# 18.575052485698322
#
# ****************** Iteration 62 ********************
# 16.60177571799218
# 18.20355143598436
#
# ****************** Iteration 63 ********************
# 16.419740203632337
# 17.839480407264674
#
# ****************** Iteration 64 ********************
# 16.24134539955969
# 17.482690799119382
#
# ****************** Iteration 65 ********************
# 16.066518491568498
# 17.133036983136996
#
# ****************** Iteration 66 ********************
# 15.895188121737128
# 16.790376243474256
#
# ****************** Iteration 67 ********************
# 15.727284359302386
# 16.454568718604772
#
# ****************** Iteration 68 ********************
# 15.562738672116339
# 16.125477344232678
#
# ****************** Iteration 69 ********************
# 15.401483898674012
# 15.802967797348025
#
# ****************** Iteration 70 ********************
# 15.243454220700531
# 15.486908441401063
#
# ****************** Iteration 71 ********************
# 15.08858513628652
# 15.17717027257304
#
# ****************** Iteration 72 ********************
# 14.93681343356079
# 14.87362686712158
#
# ****************** Iteration 73 ********************
# 14.788077164889573
# 14.576154329779147
#
# ****************** Iteration 74 ********************
# 14.642315621591782
# 14.284631243183565
#
# ****************** Iteration 75 ********************
# 14.499469309159947
# 13.998938618319894
#
# ****************** Iteration 76 ********************
# 14.359479922976748
# 13.718959845953496
#
# ****************** Iteration 77 ********************
# 14.222290324517212
# 13.444580649034425
#
# ****************** Iteration 78 ********************
# 14.087844518026868
# 13.175689036053736
#
# ****************** Iteration 79 ********************
# 13.956087627666331
# 12.912175255332663
#
# ****************** Iteration 80 ********************
# 13.826965875113006
# 12.653931750226011
#
# ****************** Iteration 81 ********************
# 13.700426557610745
# 12.40085311522149
#
# ****************** Iteration 82 ********************
# 13.57641802645853
# 12.15283605291706
#
# ****************** Iteration 83 ********************
# 13.45488966592936
# 11.909779331858719
#
# ****************** Iteration 84 ********************
# 13.335791872610772
# 11.671583745221543
#
# ****************** Iteration 85 ********************
# 13.219076035158556
# 11.438152070317113
#
# ****************** Iteration 86 ********************
# 13.104694514455385
# 11.20938902891077
#
# ****************** Iteration 87 ********************
# 12.992600624166277
# 10.985201248332555
#
# ****************** Iteration 88 ********************
# 12.882748611682953
# 10.765497223365905
#
# ****************** Iteration 89 ********************
# 12.775093639449294
# 10.550187278898587
#
# ****************** Iteration 90 ********************
# 12.669591766660307
# 10.339183533320615
#
# ****************** Iteration 91 ********************
# 12.566199931327102
# 10.132399862654204
#
# ****************** Iteration 92 ********************
# 12.46487593270056
# 9.92975186540112
#
# ****************** Iteration 93 ********************
# 12.36557841404655
# 9.731156828093098
#
# ****************** Iteration 94 ********************
# 12.268266845765618
# 9.536533691531236
#
# ****************** Iteration 95 ********************
# 12.172901508850305
# 9.34580301770061
#
# ****************** Iteration 96 ********************
# 12.0794434786733
# 9.1588869573466
#
# ****************** Iteration 97 ********************
# 11.987854609099834
# 8.975709218199668
#
# ****************** Iteration 98 ********************
# 11.898097516917838
# 8.796195033835676
#
# ****************** Iteration 99 ********************
# 11.810135566579481
# 8.620271133158962
#
# ****************** Iteration 100 ********************
# 11.723932855247892
# 8.447865710495783
#
# ****************** Iteration 101 ********************
# 11.639454198142934
# 8.278908396285868
#
# ****************** Iteration 102 ********************
# 11.556665114180076
# 8.113330228360152
#
# ****************** Iteration 103 ********************
# 11.475531811896474
# 7.9510636237929475
#
# ****************** Iteration 104 ********************
# 11.396021175658545
# 7.7920423513170896
#
# ****************** Iteration 105 ********************
# 11.318100752145375
# 7.636201504290749
#
# ****************** Iteration 106 ********************
# 11.241738737102468
# 7.4834774742049355
#
# ****************** Iteration 107 ********************
# 11.166903962360418
# 7.333807924720837
#
# ****************** Iteration 108 ********************
# 11.093565883113211
# 7.187131766226422
#
# ****************** Iteration 109 ********************
# 11.021694565450947
# 7.043389130901893
#
# ****************** Iteration 110 ********************
# 10.951260674141928
# 6.902521348283855
#
# ****************** Iteration 111 ********************
# 10.88223546065909
# 6.764470921318178
#
# ****************** Iteration 112 ********************
# 10.814590751445907
# 6.629181502891814
#
# ****************** Iteration 113 ********************
# 10.748298936416989
# 6.496597872833977
#
# ****************** Iteration 114 ********************
# 10.683332957688648
# 6.366665915377297
#
# ****************** Iteration 115 ********************
# 10.619666298534876
# 6.239332597069751
#
# ****************** Iteration 116 ********************
# 10.557272972564178
# 6.114545945128356
#
# ****************** Iteration 117 ********************
# 10.496127513112894
# 5.992255026225788
#
# ****************** Iteration 118 ********************
# 10.436204962850637
# 5.872409925701273
#
# ****************** Iteration 119 ********************
# 10.377480863593624
# 5.754961727187247
#
# ****************** Iteration 120 ********************
# 10.319931246321751
# 5.639862492643502
#
# ****************** Iteration 121 ********************
# 10.263532621395315
# 5.527065242790631
#
# ****************** Iteration 122 ********************
# 10.20826196896741
# 5.416523937934819
#
# ****************** Iteration 123 ********************
# 10.154096729588062
# 5.308193459176124
#
# ****************** Iteration 124 ********************
# 10.101014794996301
# 5.202029589992602
#
# ****************** Iteration 125 ********************
# 10.048994499096375
# 5.097988998192751
#
# ****************** Iteration 126 ********************
# 9.998014609114447
# 4.996029218228895
#
# ****************** Iteration 127 ********************
# 9.948054316932158
# 4.896108633864316
#
# ****************** Iteration 128 ********************
# 9.899093230593515
# 4.798186461187029
#
# ****************** Iteration 129 ********************
# 9.851111365981644
# 4.702222731963289
#
# ****************** Iteration 130 ********************
# 9.804089138662011
# 4.608178277324022
#
# ****************** Iteration 131 ********************
# 9.75800735588877
# 4.51601471177754
#
# ****************** Iteration 132 ********************
# 9.712847208770995
# 4.42569441754199
#
# ****************** Iteration 133 ********************
# 9.668590264595576
# 4.337180529191151
#
# ****************** Iteration 134 ********************
# 9.625218459303664
# 4.250436918607328
#
# ****************** Iteration 135 ********************
# 9.582714090117591
# 4.165428180235182
#
# ****************** Iteration 136 ********************
# 9.54105980831524
# 4.082119616630479
#
# ****************** Iteration 137 ********************
# 9.500238612148934
# 4.0004772242978675
#
# ****************** Iteration 138 ********************
# 9.460233839905955
# 3.9204676798119102
#
# ****************** Iteration 139 ********************
# 9.421029163107836
# 3.842058326215671
#
# ****************** Iteration 140 ********************
# 9.382608579845678
# 3.765217159691357
#
# ****************** Iteration 141 ********************
# 9.344956408248764
# 3.689912816497529
#
# ****************** Iteration 142 ********************
# 9.308057280083789
# 3.6161145601675777
#
# ****************** Iteration 143 ********************
# 9.271896134482112
# 3.543792268964225
#
# ****************** Iteration 144 ********************
# 9.23645821179247
# 3.472916423584941
#
# ****************** Iteration 145 ********************
# 9.20172904755662
# 3.4034580951132405
#
# ****************** Iteration 146 ********************
# 9.167694466605488
# 3.335388933210975
#
# ****************** Iteration 147 ********************
# 9.134340577273377
# 3.268681154546755
#
# ****************** Iteration 148 ********************
# 9.10165376572791
# 3.2033075314558204
#
# ****************** Iteration 149 ********************
# 9.069620690413352
# 3.1392413808267037
#
# ****************** Iteration 150 ********************
# 9.038228276605086
# 3.0764565532101713
#
# ****************** Iteration 151 ********************
# 9.007463711072983
# 3.0149274221459663
#
# ****************** Iteration 152 ********************
# 8.977314436851524
# 2.9546288737030473
#
# ****************** Iteration 153 ********************
# 8.947768148114493
# 2.895536296228986
#
# ****************** Iteration 154 ********************
# 8.918812785152204
# 2.8376255703044073
#
# ****************** Iteration 155 ********************
# 8.89043652944916
# 2.780873058898319
#
# ****************** Iteration 156 ********************
# 8.862627798860176
# 2.725255597720352
#
# ****************** Iteration 157 ********************
# 8.835375242882973
# 2.6707504857659465
#
# ****************** Iteration 158 ********************
# 8.808667738025314
# 2.617335476050627
#
# ****************** Iteration 159 ********************
# 8.782494383264808
# 2.5649887665296163
#
# ****************** Iteration 160 ********************
# 8.756844495599513
# 2.5136889911990252
#
# ****************** Iteration 161 ********************
# 8.731707605687522
# 2.463415211375043
#
# ****************** Iteration 162 ********************
# 8.707073453573772
# 2.4141469071475434
#
# ****************** Iteration 163 ********************
# 8.682931984502297
# 2.365863969004593
#
# ****************** Iteration 164 ********************
# 8.65927334481225
# 2.318546689624501
#
# ****************** Iteration 165 ********************
# 8.636087877916005
# 2.2721757558320093
#
# ****************** Iteration 166 ********************
# 8.613366120357684
# 2.226732240715368
#
# ****************** Iteration 167 ********************
# 8.59109879795053
# 2.1821975959010587
#
# ****************** Iteration 168 ********************
# 8.569276821991519
# 2.1385536439830375
#
# ****************** Iteration 169 ********************
# 8.547891285551689
# 2.0957825711033777
#
# ****************** Iteration 170 ********************
# 8.526933459840656
# 2.0538669196813117
#
# ****************** Iteration 171 ********************
# 8.506394790643842
# 2.0127895812876844
#
# ****************** Iteration 172 ********************
# 8.486266894830965
# 1.9725337896619308
#
# ****************** Iteration 173 ********************
# 8.466541556934347
# 1.933083113868694
#
# ****************** Iteration 174 ********************
# 8.44721072579566
# 1.8944214515913202
#
# ****************** Iteration 175 ********************
# 8.428266511279746
# 1.8565330225594927
#
# ****************** Iteration 176 ********************
# 8.409701181054151
# 1.8194023621083026
#
# ****************** Iteration 177 ********************
# 8.391507157433068
# 1.7830143148661364
#
# ****************** Iteration 178 ********************
# 8.373677014284407
# 1.7473540285688145
#
# ****************** Iteration 179 ********************
# 8.356203473998718
# 1.7124069479974366
#
# ****************** Iteration 180 ********************
# 8.339079404518744
# 1.6781588090374875
#
# ****************** Iteration 181 ********************
# 8.32229781642837
# 1.6445956328567384
#
# ****************** Iteration 182 ********************
# 8.305851860099802
# 1.6117037201996034
#
# ****************** Iteration 183 ********************
# 8.289734822897806
# 1.579469645795612
#
# ****************** Iteration 184 ********************
# 8.27394012643985
# 1.5478802528797004
#
# ****************** Iteration 185 ********************
# 8.258461323911053
# 1.5169226478221063
#
# ****************** Iteration 186 ********************
# 8.243292097432832
# 1.4865841948656637
#
# ****************** Iteration 187 ********************
# 8.228426255484175
# 1.45685251096835
#
# ****************** Iteration 188 ********************
# 8.21385773037449
# 1.4277154607489813
#
# ****************** Iteration 189 ********************
# 8.199580575767001
# 1.3991611515340026
#
# ****************** Iteration 190 ********************
# 8.18558896425166
# 1.3711779285033217
#
# ****************** Iteration 191 ********************
# 8.171877184966627
# 1.3437543699332544
#
# ****************** Iteration 192 ********************
# 8.158439641267295
# 1.3168792825345896
#
# ****************** Iteration 193 ********************
# 8.14527084844195
# 1.2905416968838992
#
# ****************** Iteration 194 ********************
# 8.13236543147311
# 1.2647308629462195
#
# ****************** Iteration 195 ********************
# 8.119718122843647
# 1.239436245687294
#
# ****************** Iteration 196 ********************
# 8.107323760386775
# 1.2146475207735499
#
# ****************** Iteration 197 ********************
# 8.09517728517904
# 1.1903545703580782
#
# ****************** Iteration 198 ********************
# 8.083273739475459
# 1.1665474789509176
#
# ****************** Iteration 199 ********************
# 8.071608264685949
# 1.143216529371898
#
# ****************** Iteration 200 ********************
# 8.06017609939223
# 1.1203521987844596
#
# ****************** Iteration 201 ********************
# 8.048972577404385
# 1.0979451548087695
#
# ****************** Iteration 202 ********************
# 8.037993125856296
# 1.0759862517125924
#
# ****************** Iteration 203 ********************
# 8.02723326333917
# 1.0544665266783397
#
# ****************** Iteration 204 ********************
# 8.016688598072387
# 1.033377196144773
#
# ****************** Iteration 205 ********************
# 8.00635482611094
# 1.0127096522218793
#
# ****************** Iteration 206 ********************
# 7.996227729588721
# 0.9924554591774424
#
# ****************** Iteration 207 ********************
# 7.986303174996947
# 0.9726063499938942
#
# ****************** Iteration 208 ********************
# 7.976577111497008
# 0.9531542229940158
#
# ****************** Iteration 209 ********************
# 7.967045569267068
# 0.9340911385341357
#
# ****************** Iteration 210 ********************
# 7.9577046578817265
# 0.9154093157634531
#
# ****************** Iteration 211 ********************
# 7.948550564724092
# 0.8971011294481848
#
# ****************** Iteration 212 ********************
# 7.939579553429611
# 0.8791591068592215
#
# ****************** Iteration 213 ********************
# 7.930787962361019
# 0.8615759247220378
#
# ****************** Iteration 214 ********************
# 7.922172203113798
# 0.8443444062275969
#
# ****************** Iteration 215 ********************
# 7.913728759051523
# 0.8274575181030457
#
# ****************** Iteration 216 ********************
# 7.905454183870493
# 0.8109083677409856
#
# ****************** Iteration 217 ********************
# 7.897345100193083
# 0.7946902003861656
#
# ****************** Iteration 218 ********************
# 7.889398198189221
# 0.7787963963784428
#
# ****************** Iteration 219 ********************
# 7.881610234225437
# 0.7632204684508732
#
# ****************** Iteration 220 ********************
# 7.873978029540928
# 0.7479560590818561
#
# ****************** Iteration 221 ********************
# 7.86649846895011
# 0.7329969379002197
#
# ****************** Iteration 222 ********************
# 7.8591684995711075
# 0.718336999142215
#
# ****************** Iteration 223 ********************
# 7.851985129579686
# 0.7039702591593713
#
# ****************** Iteration 224 ********************
# 7.844945426988092
# 0.6898908539761841
#
# ****************** Iteration 225 ********************
# 7.83804651844833
# 0.6760930368966598
#
# ****************** Iteration 226 ********************
# 7.831285588079363
# 0.6625711761587265
#
# ****************** Iteration 227 ********************
# 7.824659876317776
# 0.6493197526355523
#
# ****************** Iteration 228 ********************
# 7.818166678791421
# 0.636333357582842
#
# ****************** Iteration 229 ********************
# 7.811803345215592
# 0.6236066904311848
#
# ****************** Iteration 230 ********************
# 7.805567278311281
# 0.6111345566225612
#
# ****************** Iteration 231 ********************
# 7.7994559327450546
# 0.5989118654901091
#
# ****************** Iteration 232 ********************
# 7.793466814090153
# 0.5869336281803061
#
# ****************** Iteration 233 ********************
# 7.78759747780835
# 0.5751949556167002
#
# ****************** Iteration 234 ********************
# 7.781845528252183
# 0.563691056504366
#
# ****************** Iteration 235 ********************
# 7.776208617687139
# 0.5524172353742784
#
# ****************** Iteration 236 ********************
# 7.770684445333396
# 0.5413688906667922
#
# ****************** Iteration 237 ********************
# 7.7652707564267285
# 0.530541512853457
#
# ****************** Iteration 238 ********************
# 7.7599653412981935
# 0.519930682596387
#
# ****************** Iteration 239 ********************
# 7.75476603447223
# 0.5095320689444591
#
# ****************** Iteration 240 ********************
# 7.749670713782785
# 0.4993414275655699
#
# ****************** Iteration 241 ********************
# 7.74467729950713
# 0.48935459901425915
#
# ****************** Iteration 242 ********************
# 7.739783753516987
# 0.47956750703397333
#
# ****************** Iteration 243 ********************
# 7.734988078446647
# 0.46997615689329386
#
# ****************** Iteration 244 ********************
# 7.730288316877714
# 0.46057663375542823
#
# ****************** Iteration 245 ********************
# 7.72568255054016
# 0.45136510108032013
#
# ****************** Iteration 246 ********************
# 7.721168899529357
# 0.4423377990587145
#
# ****************** Iteration 247 ********************
# 7.71674552153877
# 0.43349104307753983
#
# ****************** Iteration 248 ********************
# 7.712410611107995
# 0.4248212222159893
#
# ****************** Iteration 249 ********************
# 7.708162398885834
# 0.41632479777166864
#
# ****************** Iteration 250 ********************
# 7.703999150908118
# 0.4079983018162352
#
# ****************** Iteration 251 ********************
# 7.699919167889956
# 0.39983833577991135
#
# ****************** Iteration 252 ********************
# 7.695920784532157
# 0.39184156906431333
#
# ****************** Iteration 253 ********************
# 7.692002368841513
# 0.3840047376830267
#
# ****************** Iteration 254 ********************
# 7.6881623214646835
# 0.37632464292936696
#
# ****************** Iteration 255 ********************
# 7.684399075035389
# 0.3687981500707789
#
# ****************** Iteration 256 ********************
# 7.680711093534682
# 0.3614221870693637
#
# ****************** Iteration 257 ********************
# 7.677096871663988
# 0.3541937433279756
#
# ****************** Iteration 258 ********************
# 7.673554934230708
# 0.3471098684614162
#
# ****************** Iteration 259 ********************
# 7.670083835546094
# 0.34016767109218726
#
# ****************** Iteration 260 ********************
# 7.6666821588351715
# 0.3333643176703429
#
# ****************** Iteration 261 ********************
# 7.663348515658468
# 0.32669703131693595
#
# ****************** Iteration 262 ********************
# 7.660081545345299
# 0.32016309069059723
#
# ****************** Iteration 263 ********************
# 7.6568799144383926
# 0.3137598288767851
#
# ****************** Iteration 264 ********************
# 7.653742316149625
# 0.30748463229924994
#
# ****************** Iteration 265 ********************
# 7.650667469826632
# 0.3013349396532643
#
# ****************** Iteration 266 ********************
# 7.6476541204301
# 0.2953082408601997
#
# ****************** Iteration 267 ********************
# 7.6447010380214975
# 0.28940207604299495
#
# ****************** Iteration 268 ********************
# 7.641807017261067
# 0.2836140345221345
#
# ****************** Iteration 269 ********************
# 7.638970876915846
# 0.2779417538316924
#
# ****************** Iteration 270 ********************
# 7.636191459377529
# 0.27238291875505816
#
# ****************** Iteration 271 ********************
# 7.633467630189979
# 0.26693526037995774
#
# ****************** Iteration 272 ********************
# 7.630798277586179
# 0.2615965551723587
#
# ****************** Iteration 273 ********************
# 7.628182312034456
# 0.2563646240689117
#
# ****************** Iteration 274 ********************
# 7.625618665793767
# 0.25123733158753403
#
# ****************** Iteration 275 ********************
# 7.623106292477892
# 0.24621258495578324
#
# ****************** Iteration 276 ********************
# 7.620644166628334
# 0.24128833325666754
#
# ****************** Iteration 277 ********************
# 7.618231283295767
# 0.23646256659153408
#
# ****************** Iteration 278 ********************
# 7.6158666576298515
# 0.23173331525970298
#
# ****************** Iteration 279 ********************
# 7.613549324477255
# 0.22709864895450949
#
# ****************** Iteration 280 ********************
# 7.611278337987709
# 0.22255667597541873
#
# ****************** Iteration 281 ********************
# 7.609052771227955
# 0.21810554245591085
#
# ****************** Iteration 282 ********************
# 7.606871715803396
# 0.2137434316067921
#
# ****************** Iteration 283 ********************
# 7.604734281487328
# 0.20946856297465644
#
# ****************** Iteration 284 ********************
# 7.602639595857582
# 0.20527919171516373
#
# ****************** Iteration 285 ********************
# 7.6005868039404305
# 0.20117360788086103
#
# ****************** Iteration 286 ********************
# 7.5985750678616215
# 0.19715013572324303
#
# ****************** Iteration 287 ********************
# 7.596603566504389
# 0.19320713300877834
#
# ****************** Iteration 288 ********************
# 7.5946714951743015
# 0.18934299034860302
#
# ****************** Iteration 289 ********************
# 7.5927780652708154
# 0.1855561305416309
#
# ****************** Iteration 290 ********************
# 7.590922503965399
# 0.18184500793079827
#
# ****************** Iteration 291 ********************
# 7.589104053886091
# 0.178208107772182
#
# ****************** Iteration 292 ********************
# 7.587321972808369
# 0.17464394561673835
#
# ****************** Iteration 293 ********************
# 7.585575533352202
# 0.17115106670440383
#
# ****************** Iteration 294 ********************
# 7.583864022685158
# 0.16772804537031583
#
# ****************** Iteration 295 ********************
# 7.582186742231455
# 0.1643734844629101
#
# ****************** Iteration 296 ********************
# 7.580543007386826
# 0.1610860147736517
#
# ****************** Iteration 297 ********************
# 7.578932147239089
# 0.15786429447817873
#
# ****************** Iteration 298 ********************
# 7.577353504294307
# 0.15470700858861441
#
# ****************** Iteration 299 ********************
# 7.575806434208421
# 0.15161286841684252
#
# ****************** Iteration 300 ********************
# 7.5742903055242525
# 0.14858061104850506
#
# ****************** Iteration 301 ********************
# 7.572804499413768
# 0.14560899882753553
#
# ****************** Iteration 302 ********************
# 7.571348409425492
# 0.14269681885098429
#
# ****************** Iteration 303 ********************
# 7.569921441236982
# 0.13984288247396393
#
# ****************** Iteration 304 ********************
# 7.568523012412243
# 0.13704602482448536
#
# ****************** Iteration 305 ********************
# 7.567152552163998
# 0.13430510432799636
#
# ****************** Iteration 306 ********************
# 7.565809501120718
# 0.13161900224143608
#
# ****************** Iteration 307 ********************
# 7.564493311098303
# 0.1289866221966065
#
# ****************** Iteration 308 ********************
# 7.563203444876337
# 0.12640688975267445
#
# ****************** Iteration 309 ********************
# 7.5619393759788105
# 0.12387875195762099
#
# ****************** Iteration 310 ********************
# 7.560700588459234
# 0.12140117691846797
#
# ****************** Iteration 311 ********************
# 7.559486576690049
# 0.1189731533800984
#
# ****************** Iteration 312 ********************
# 7.5582968451562484
# 0.11659369031249689
#
# ****************** Iteration 313 ********************
# 7.557130908253123
# 0.11426181650624656
#
# ****************** Iteration 314 ********************
# 7.55598829008806
# 0.11197658017612078
#
# ****************** Iteration 315 ********************
# 7.554868524286299
# 0.10973704857259747
#
# ****************** Iteration 316 ********************
# 7.5537711538005725
# 0.10754230760114503
#
# ****************** Iteration 317 ********************
# 7.552695730724561
# 0.10539146144912159
#
# ****************** Iteration 318 ********************
# 7.551641816110069
# 0.1032836322201387
#
# ****************** Iteration 319 ********************
# 7.550608979787868
# 0.10121795957573632
#
# ****************** Iteration 320 ********************
# 7.549596800192111
# 0.09919360038422198

# %%
print(f"D Results with x0 =40, lr=0.01, epsilon=0.1\nFound solution after {i} iterations.")
print("x_min =" , x_min)
print( 'Gradient = ', grad )
# Out:
# D Results with x0 =40, lr=0.01, epsilon=0.1
# Found solution after 320 iterations.
# x_min = 7.549596800192111
# Gradient =  0.09919360038422198

# %%
# Gradient descent with learning rate = 0.01, x0=40, epsilon = 0.1
# Out:
# GD Results with x0 =40, lr=0.01, epsilon=0.1
# Found solution after 321 iterations.
# x_min = 7.549596800192111
# Gradient = 0.09919360038422198

# %%
def Newton(x0, max_it, df ,ddf):
    x=x0
     
    for i in range(max_it):
        print(f"\n****************** Iteration {i} ********************")
        x=x-df(x)/ddf(x)
        print(x)
        gred=np.abs(df(x))
        print(gred)
        if gred < 0.01:
            break
        
     
    
    return x,gred,i
 
x_min,gred,i = Newton(40,400,Df,DDf)
# Out:
# ****************** Iteration 0 ********************
# 7.5
# 0.0

# %%
print(f"Newton Results with x0 =40, epsilon=0.1\nFound solution after {i+1} iterations.")
print("x_min =" , x_min)
print( 'Gradient = ', gred )
# Out:
# Newton Results with x0 =40, epsilon=0.1
# Found solution after 1 iterations.
# x_min = 7.5
# Gradient =  0.0

# %%
# Newton's method without learning rate, x0=40, epsilon = 0.1
# Out:
# Newton Results with x0 =40, epsilon=0.1
# Found solution after 1 iterations.
# x_min = 7.5
# Gradient = 0.0

# %%
def Newton_Rate(x0, max_it,rate, df ,ddf):
    x=x0
     
    for i in range(max_it):
        print(f"\n****************** Iteration {i} ********************")
        x=x- (df(x)/ddf(x))*rate
        print(x)
        gred=np.abs(df(x))
        print(gred)
        if gred < 0.1:
            break
        
     
    
    return x,gred,i

 
x_min , gred ,i= Newton_Rate(40,200,0.8,Df,DDf)
# Out:
# ****************** Iteration 0 ********************
# 14.0
# 13.0
#
# ****************** Iteration 1 ********************
# 8.8
# 2.6000000000000014
#
# ****************** Iteration 2 ********************
# 7.76
# 0.5199999999999996
#
# ****************** Iteration 3 ********************
# 7.552
# 0.1039999999999992
#
# ****************** Iteration 4 ********************
# 7.5104
# 0.020799999999999486

# %%
print(f"Newton Results  with x0 =40, epsilon=0.1, lr=0.8\nFound solution after {i+1} iterations.")
print("x_min =" , x_min)
print( 'Gradient = ', gred )
# Out:
# Newton Results  with x0 =40, epsilon=0.1, lr=0.8
# Found solution after 5 iterations.
# x_min = 7.5104
# Gradient =  0.020799999999999486

# %%
# Newton's method with learning rate = 0.8, x0=40, epsilon = 0.1
# Out:
# Newton Results  with x0 =40, epsilon=0.1, lr=0.8
# Found solution after 5 iterations.
# x_min = 7.5104
# Gradient = 0.020799999999999486

# %% [markdown]
# ### Multi Variable
# - Implement the <b>Gradient decent and Newton's method</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐+xy+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐y$
# - The stop condition is grad < epsilon.
# - Try different epsilons and initial conditions.
# - Compare the results with Gradient descent.
# ##### The function shgould return the solution and the gradient.

# %%
from sympy import *
from sympy.plotting import plot3d

# %% [markdown]
# $𝒇(𝒙)=𝒙^𝟐+y^2$

# %%
x,y = symbols('x y')
f = x**2 + y**2
plot3d(f,size=(8,6))
plt.show()

# %% [markdown]
# $𝒇(𝒙)=𝒙^𝟐+xy+y^2$

# %%
x,y = symbols('x y')
f = x**2 + x * y + y**2
plot3d(f,size=(10,7))
plt.show()

# %% [markdown]
# $𝒇(𝒙)=𝒙^𝟐y$

# %%
x,y = symbols('x y')
f = x**2 * y
plot3d(f,size=(10,7))
plt.show()

# %%
f_1 = lambda x: x**2  + y**2
Df_1 = lambda X: np.array([2*X[0],2*X[1]])
DDf_1 = lambda X: np.array([[2,0],
                         [0,2]])

# %% [markdown]
# - $𝒇(𝒙)=𝒙^𝟐+xy+y^2$

# %%
f_2 = lambda x: x**2 + x*y + y**2
Df_2 = lambda X: np.array([2*X[0]+X[1],2*X[1]+X[0]])
DDf_2 = lambda X: np.array([[2,1],
                        [1,2]])

# %%
np.abs(Df_1((10,10)))
# Out:
# array([20, 20])

# %%
def Gradient_Multi(x0, max_it,alpha ,epsilon, df ):
    x=x0
     
    for i in range(max_it):
        print(f"\n****************** Iteration {i} ********************")
        x = x -  (df(x) *alpha)
        print("xy =  ",x)
        grad = np.abs(df(x))
        print("grad=",grad)
        if grad[0] < epsilon and grad[1] < epsilon:
            break
#         if grad.sum() < epsilon :
#             break
        
    print(f"\n\n****************** Training Report ********************")  
    print(f"Found solution after {i+1} iterations.")
    print("xy_min =" , x)
    print('Gradient=', grad )
     
    
    return x , grad ,i

# %%
xy_min , grad , i = Gradient_Multi( (10,10) , 400,  0.1, 0.001 , Df_1)
# Out:
# ****************** Iteration 0 ********************
# xy =   [8. 8.]
# grad= [16. 16.]
#
# ****************** Iteration 1 ********************
# xy =   [6.4 6.4]
# grad= [12.8 12.8]
#
# ****************** Iteration 2 ********************
# xy =   [5.12 5.12]
# grad= [10.24 10.24]
#
# ****************** Iteration 3 ********************
# xy =   [4.096 4.096]
# grad= [8.192 8.192]
#
# ****************** Iteration 4 ********************
# xy =   [3.2768 3.2768]
# grad= [6.5536 6.5536]
#
# ****************** Iteration 5 ********************
# xy =   [2.62144 2.62144]
# grad= [5.24288 5.24288]
#
# ****************** Iteration 6 ********************
# xy =   [2.097152 2.097152]
# grad= [4.194304 4.194304]
#
# ****************** Iteration 7 ********************
# xy =   [1.6777216 1.6777216]
# grad= [3.3554432 3.3554432]
#
# ****************** Iteration 8 ********************
# xy =   [1.34217728 1.34217728]
# grad= [2.68435456 2.68435456]
#
# ****************** Iteration 9 ********************
# xy =   [1.07374182 1.07374182]
# grad= [2.14748365 2.14748365]
#
# ****************** Iteration 10 ********************
# xy =   [0.85899346 0.85899346]
# grad= [1.71798692 1.71798692]
#
# ****************** Iteration 11 ********************
# xy =   [0.68719477 0.68719477]
# grad= [1.37438953 1.37438953]
#
# ****************** Iteration 12 ********************
# xy =   [0.54975581 0.54975581]
# grad= [1.09951163 1.09951163]
#
# ****************** Iteration 13 ********************
# xy =   [0.43980465 0.43980465]
# grad= [0.8796093 0.8796093]
#
# ****************** Iteration 14 ********************
# xy =   [0.35184372 0.35184372]
# grad= [0.70368744 0.70368744]
#
# ****************** Iteration 15 ********************
# xy =   [0.28147498 0.28147498]
# grad= [0.56294995 0.56294995]
#
# ****************** Iteration 16 ********************
# xy =   [0.22517998 0.22517998]
# grad= [0.45035996 0.45035996]
#
# ****************** Iteration 17 ********************
# xy =   [0.18014399 0.18014399]
# grad= [0.36028797 0.36028797]
#
# ****************** Iteration 18 ********************
# xy =   [0.14411519 0.14411519]
# grad= [0.28823038 0.28823038]
#
# ****************** Iteration 19 ********************
# xy =   [0.11529215 0.11529215]
# grad= [0.2305843 0.2305843]
#
# ****************** Iteration 20 ********************
# xy =   [0.09223372 0.09223372]
# grad= [0.18446744 0.18446744]
#
# ****************** Iteration 21 ********************
# xy =   [0.07378698 0.07378698]
# grad= [0.14757395 0.14757395]
#
# ****************** Iteration 22 ********************
# xy =   [0.05902958 0.05902958]
# grad= [0.11805916 0.11805916]
#
# ****************** Iteration 23 ********************
# xy =   [0.04722366 0.04722366]
# grad= [0.09444733 0.09444733]
#
# ****************** Iteration 24 ********************
# xy =   [0.03777893 0.03777893]
# grad= [0.07555786 0.07555786]
#
# ****************** Iteration 25 ********************
# xy =   [0.03022315 0.03022315]
# grad= [0.06044629 0.06044629]
#
# ****************** Iteration 26 ********************
# xy =   [0.02417852 0.02417852]
# grad= [0.04835703 0.04835703]
#
# ****************** Iteration 27 ********************
# xy =   [0.01934281 0.01934281]
# grad= [0.03868563 0.03868563]
#
# ****************** Iteration 28 ********************
# xy =   [0.01547425 0.01547425]
# grad= [0.0309485 0.0309485]
#
# ****************** Iteration 29 ********************
# xy =   [0.0123794 0.0123794]
# grad= [0.0247588 0.0247588]
#
# ****************** Iteration 30 ********************
# xy =   [0.00990352 0.00990352]
# grad= [0.01980704 0.01980704]
#
# ****************** Iteration 31 ********************
# xy =   [0.00792282 0.00792282]
# grad= [0.01584563 0.01584563]
#
# ****************** Iteration 32 ********************
# xy =   [0.00633825 0.00633825]
# grad= [0.01267651 0.01267651]
#
# ****************** Iteration 33 ********************
# xy =   [0.0050706 0.0050706]
# grad= [0.0101412 0.0101412]
#
# ****************** Iteration 34 ********************
# xy =   [0.00405648 0.00405648]
# grad= [0.00811296 0.00811296]
#
# ****************** Iteration 35 ********************
# xy =   [0.00324519 0.00324519]
# grad= [0.00649037 0.00649037]
#
# ****************** Iteration 36 ********************
# xy =   [0.00259615 0.00259615]
# grad= [0.0051923 0.0051923]
#
# ****************** Iteration 37 ********************
# xy =   [0.00207692 0.00207692]
# grad= [0.00415384 0.00415384]
#
# ****************** Iteration 38 ********************
# xy =   [0.00166153 0.00166153]
# grad= [0.00332307 0.00332307]
#
# ****************** Iteration 39 ********************
# xy =   [0.00132923 0.00132923]
# grad= [0.00265846 0.00265846]
#
# ****************** Iteration 40 ********************
# xy =   [0.00106338 0.00106338]
# grad= [0.00212676 0.00212676]
#
# ****************** Iteration 41 ********************
# xy =   [0.00085071 0.00085071]
# grad= [0.00170141 0.00170141]
#
# ****************** Iteration 42 ********************
# xy =   [0.00068056 0.00068056]
# grad= [0.00136113 0.00136113]
#
# ****************** Iteration 43 ********************
# xy =   [0.00054445 0.00054445]
# grad= [0.0010889 0.0010889]
#
# ****************** Iteration 44 ********************
# xy =   [0.00043556 0.00043556]
# grad= [0.00087112 0.00087112]
#
#
# ****************** Training Report ********************
# Found solution after 45 iterations.
# xy_min = [0.00043556 0.00043556]
# Gradient= [0.00087112 0.00087112]

# %%
# First function
# Multi-variable Gradient descent with learning rate = 0.1,
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 46 iterations.
# xy_min = [0.00034845 0.00034845]
# Gradient = [0.0006969 0.0006969]

# %%
x_min , grad , i = Gradient_Multi( (10,10) , 400,  0.5, 0.001 , Df_1)
# Out:
# ****************** Iteration 0 ********************
# xy =   [0. 0.]
# grad= [0. 0.]
#
#
# ****************** Training Report ********************
# Found solution after 1 iterations.
# xy_min = [0. 0.]
# Gradient= [0. 0.]

# %%
# First function
# Multi-variable Gradient descent with learning rate = 0.5,
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 1 iterations.
# xy_min = [0. 0.]
# Gradient = [0. 0.]

# %%
def Newton_Multi(x0, max_it ,alpha, epsilon, df ,ddf):
    x=x0
     
    for i in range(max_it):
        print(f"\n****************** Iteration {i} ********************")
        x = x - alpha*(np.linalg.inv(ddf(x)) @ df(x))
        print("xy = ",x)
        grad = np.abs(df(x))
        print("grad=",grad)
        if grad[0] < epsilon and grad[1] < epsilon:
            break
        
    print(f"\n\n****************** Training Report ********************")  
    print(f"Found solution after {i+1} iterations.")
    print("xy_min =" , x)
    print('Gradient=',grad )
    
    return x , grad ,i
 
x_min , gred ,i = Newton_Multi((10,10), 200 ,1, 0.001 , Df_1 , DDf_1)
# Out:
# ****************** Iteration 0 ********************
# xy =  [0. 0.]
# grad= [0. 0.]
#
#
# ****************** Training Report ********************
# Found solution after 1 iterations.
# xy_min = [0. 0.]
# Gradient= [0. 0.]

# %%
# First function
# Multi-variable Newton's method without learning rate, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 1 iterations.
# xy_min = [0. 0.]
# Gradient = [0. 0.]

# %%
x_min , gred ,i = Newton_Multi((10,10), 200 ,0.5, 0.001 , Df_1 , DDf_1)
# Out:
# ****************** Iteration 0 ********************
# xy =  [5. 5.]
# grad= [10. 10.]
#
# ****************** Iteration 1 ********************
# xy =  [2.5 2.5]
# grad= [5. 5.]
#
# ****************** Iteration 2 ********************
# xy =  [1.25 1.25]
# grad= [2.5 2.5]
#
# ****************** Iteration 3 ********************
# xy =  [0.625 0.625]
# grad= [1.25 1.25]
#
# ****************** Iteration 4 ********************
# xy =  [0.3125 0.3125]
# grad= [0.625 0.625]
#
# ****************** Iteration 5 ********************
# xy =  [0.15625 0.15625]
# grad= [0.3125 0.3125]
#
# ****************** Iteration 6 ********************
# xy =  [0.078125 0.078125]
# grad= [0.15625 0.15625]
#
# ****************** Iteration 7 ********************
# xy =  [0.0390625 0.0390625]
# grad= [0.078125 0.078125]
#
# ****************** Iteration 8 ********************
# xy =  [0.01953125 0.01953125]
# grad= [0.0390625 0.0390625]
#
# ****************** Iteration 9 ********************
# xy =  [0.00976562 0.00976562]
# grad= [0.01953125 0.01953125]
#
# ****************** Iteration 10 ********************
# xy =  [0.00488281 0.00488281]
# grad= [0.00976562 0.00976562]
#
# ****************** Iteration 11 ********************
# xy =  [0.00244141 0.00244141]
# grad= [0.00488281 0.00488281]
#
# ****************** Iteration 12 ********************
# xy =  [0.0012207 0.0012207]
# grad= [0.00244141 0.00244141]
#
# ****************** Iteration 13 ********************
# xy =  [0.00061035 0.00061035]
# grad= [0.0012207 0.0012207]
#
# ****************** Iteration 14 ********************
# xy =  [0.00030518 0.00030518]
# grad= [0.00061035 0.00061035]
#
#
# ****************** Training Report ********************
# Found solution after 15 iterations.
# xy_min = [0.00030518 0.00030518]
# Gradient= [0.00061035 0.00061035]

# %%
# First function
# Multi-variable Newton's method with learning rate = 0.5, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 15 iterations.
# xy_min = [0.00030518 0.00030518]
# Gradient = [0.00061035 0.00061035]

# %%
xy_min , grad , i = Gradient_Multi( (10,10) , 400,  0.5, 0.001 , Df_2)
# Out:
# ****************** Iteration 0 ********************
# xy =   [-5. -5.]
# grad= [15. 15.]
#
# ****************** Iteration 1 ********************
# xy =   [2.5 2.5]
# grad= [7.5 7.5]
#
# ****************** Iteration 2 ********************
# xy =   [-1.25 -1.25]
# grad= [3.75 3.75]
#
# ****************** Iteration 3 ********************
# xy =   [0.625 0.625]
# grad= [1.875 1.875]
#
# ****************** Iteration 4 ********************
# xy =   [-0.3125 -0.3125]
# grad= [0.9375 0.9375]
#
# ****************** Iteration 5 ********************
# xy =   [0.15625 0.15625]
# grad= [0.46875 0.46875]
#
# ****************** Iteration 6 ********************
# xy =   [-0.078125 -0.078125]
# grad= [0.234375 0.234375]
#
# ****************** Iteration 7 ********************
# xy =   [0.0390625 0.0390625]
# grad= [0.1171875 0.1171875]
#
# ****************** Iteration 8 ********************
# xy =   [-0.01953125 -0.01953125]
# grad= [0.05859375 0.05859375]
#
# ****************** Iteration 9 ********************
# xy =   [0.00976562 0.00976562]
# grad= [0.02929688 0.02929688]
#
# ****************** Iteration 10 ********************
# xy =   [-0.00488281 -0.00488281]
# grad= [0.01464844 0.01464844]
#
# ****************** Iteration 11 ********************
# xy =   [0.00244141 0.00244141]
# grad= [0.00732422 0.00732422]
#
# ****************** Iteration 12 ********************
# xy =   [-0.0012207 -0.0012207]
# grad= [0.00366211 0.00366211]
#
# ****************** Iteration 13 ********************
# xy =   [0.00061035 0.00061035]
# grad= [0.00183105 0.00183105]
#
# ****************** Iteration 14 ********************
# xy =   [-0.00030518 -0.00030518]
# grad= [0.00091553 0.00091553]
#
#
# ****************** Training Report ********************
# Found solution after 15 iterations.
# xy_min = [-0.00030518 -0.00030518]
# Gradient= [0.00091553 0.00091553]

# %%
# Second function
# Multi-variable Gradient descent with learning rate = 0.5,
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 16 iterations.
# xy_min = [0.00015259 0.00015259]
# Gradient = [0.00045776 0.00045776]

# %%
xy_min , grad , i = Newton_Multi( (10,10) , 400,  1, 0.001 , Df_2 , DDf_2)
# Out:
# ****************** Iteration 0 ********************
# xy =  [1.77635684e-15 0.00000000e+00]
# grad= [3.55271368e-15 1.77635684e-15]
#
#
# ****************** Training Report ********************
# Found solution after 1 iterations.
# xy_min = [1.77635684e-15 0.00000000e+00]
# Gradient= [3.55271368e-15 1.77635684e-15]

# %%
# Second function
# Multi-variable Newton's method without learning rate, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 1 iterations.
# xy_min = [0. 0.]
# Gradient = [0. 0.]

# %%
xy_min , grad , i = Newton_Multi( (10,10) , 400, 0.9, 0.001 , Df_2 , DDf_2)
# Out:
# ****************** Iteration 0 ********************
# xy =  [1. 1.]
# grad= [3. 3.]
#
# ****************** Iteration 1 ********************
# xy =  [0.1 0.1]
# grad= [0.3 0.3]
#
# ****************** Iteration 2 ********************
# xy =  [0.01 0.01]
# grad= [0.03 0.03]
#
# ****************** Iteration 3 ********************
# xy =  [0.001 0.001]
# grad= [0.003 0.003]
#
# ****************** Iteration 4 ********************
# xy =  [0.0001 0.0001]
# grad= [0.0003 0.0003]
#
#
# ****************** Training Report ********************
# Found solution after 5 iterations.
# xy_min = [0.0001 0.0001]
# Gradient= [0.0003 0.0003]

# %%
# Second function
# Multi-variable Newton's method with learning rate = 0.9, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 5 iterations.
# xy_min = [0.0001 0.0001]
# Gradient = [0.0003 0.0003]

# %%
f_5 = lambda x: x**2 * y
Df_5 = lambda X: np.array([2*X[0]*X[1],
                           X[0]**2])
DDf_5 = lambda X: np.array([[2*X[1],2*X[0]],
                         [2*X[0],0]])

# %%
xy_min , grad , i = Gradient_Multi( (10,10) , 400,  0.01, 0.001 , Df_5)
# Out:
# ****************** Iteration 0 ********************
# xy =   [8. 9.]
# grad= [144.  64.]
#
# ****************** Iteration 1 ********************
# xy =   [6.56 8.36]
# grad= [109.6832  43.0336]
#
# ****************** Iteration 2 ********************
# xy =   [5.463168 7.929664]
# grad= [86.64217323 29.8462046 ]
#
# ****************** Iteration 3 ********************
# xy =   [4.59674627 7.63120195]
# grad= [70.1573982  21.13007625]
#
# ****************** Iteration 4 ********************
# xy =   [3.89517229 7.41990119]
# grad= [57.80358697 15.17236714]
#
# ****************** Iteration 5 ********************
# xy =   [3.31713642 7.26817752]
# grad= [48.21907266 11.003394  ]
#
# ****************** Iteration 6 ********************
# xy =   [2.83494569 7.15814358]
# grad= [40.58589657  8.03691706]
#
# ****************** Iteration 7 ********************
# xy =   [2.42908672 7.07777441]
# grad= [34.3850557   5.90046231]
#
# ****************** Iteration 8 ********************
# xy =   [2.08523617 7.01876979]
# grad= [29.27158521  4.34820987]
#
# ****************** Iteration 9 ********************
# xy =   [1.79252031 6.97528769]
# grad= [25.00668976  3.21312908]
#
# ****************** Iteration 10 ********************
# xy =   [1.54245342 6.9431564 ]
# grad= [21.41899062  2.37916254]
#
# ****************** Iteration 11 ********************
# xy =   [1.32826351 6.91936477]
# grad= [18.38147949  1.76428395]
#
# ****************** Iteration 12 ********************
# xy =   [1.14444872 6.90172193]
# grad= [15.79733361  1.30976286]
#
# ****************** Iteration 13 ********************
# xy =   [0.98647538 6.8886243 ]
# grad= [13.59091655  0.97313368]
#
# ****************** Iteration 14 ********************
# xy =   [0.85056621 6.87889297]
# grad= [11.7019079   0.72346288]
#
# ****************** Iteration 15 ********************
# xy =   [0.73354714 6.87165834]
# grad= [10.08137058  0.5380914 ]
#
# ****************** Iteration 16 ********************
# xy =   [0.63273343 6.86627742]
# grad= [8.68904653 0.40035159]
#
# ****************** Iteration 17 ********************
# xy =   [0.54584296 6.86227391]
# grad= [7.49144786 0.29794454]
#
# ****************** Iteration 18 ********************
# xy =   [0.47092849 6.85929446]
# grad= [6.46047431 0.22177364]
#
# ****************** Iteration 19 ********************
# xy =   [0.40632374 6.85707673]
# grad= [5.57238616 0.16509898]
#
# ****************** Iteration 20 ********************
# xy =   [0.35059988 6.85542574]
# grad= [4.80702289 0.12292028]
#
# ****************** Iteration 21 ********************
# xy =   [0.30252965 6.85419653]
# grad= [4.14719539 0.09152419]
#
# ****************** Iteration 22 ********************
# xy =   [0.2610577  6.85328129]
# grad= [3.57820368 0.06815112]
#
# ****************** Iteration 23 ********************
# xy =   [0.22527566 6.85259978]
# grad= [3.0874479  0.05074912]
#
# ****************** Iteration 24 ********************
# xy =   [0.19440118 6.85209229]
# grad= [2.66410969 0.03779182]
#
# ****************** Iteration 25 ********************
# xy =   [0.16776009 6.85171437]
# grad= [2.29888838 0.02814345]
#
# ****************** Iteration 26 ********************
# xy =   [0.1447712  6.85143294]
# grad= [1.98378036 0.0209587 ]
#
# ****************** Iteration 27 ********************
# xy =   [0.1249334  6.85122335]
# grad= [1.71189323 0.01560835]
#
# ****************** Iteration 28 ********************
# xy =   [0.10781447 6.85106727]
# grad= [1.47728832 0.01162396]
#
# ****************** Iteration 29 ********************
# xy =   [0.09304158 6.85095103]
# grad= [1.27484665 0.00865674]
#
# ****************** Iteration 30 ********************
# xy =   [0.08029312 6.85086446]
# grad= [1.10015451 0.00644698]
#
# ****************** Iteration 31 ********************
# xy =   [0.06929157 6.85079999]
# grad= [0.94940539 0.00480132]
#
# ****************** Iteration 32 ********************
# xy =   [0.05979752 6.85075198]
# grad= [0.81931592 0.00357574]
#
# ****************** Iteration 33 ********************
# xy =   [0.05160436 6.85071622]
# grad= [0.70705362 0.00266301]
#
# ****************** Iteration 34 ********************
# xy =   [0.04453382 6.85068959]
# grad= [0.61017478 0.00198326]
#
# ****************** Iteration 35 ********************
# xy =   [0.03843207 6.85066976]
# grad= [0.52657089 0.00147702]
#
# ****************** Iteration 36 ********************
# xy =   [0.03316637 6.85065499]
# grad= [0.45442265 0.00110001]
#
# ****************** Iteration 37 ********************
# xy =   [0.02862214 6.85064399]
# grad= [0.39216016 0.00081923]
#
# ****************** Iteration 38 ********************
# xy =   [0.02470054 6.85063579]
# grad= [0.33842876 0.00061012]
#
# ****************** Iteration 39 ********************
# xy =   [0.02131625 6.85062969]
# grad= [0.29205946 0.00045438]
#
# ****************** Iteration 40 ********************
# xy =   [0.01839565 6.85062515]
# grad= [0.25204347 0.0003384 ]
#
# ****************** Iteration 41 ********************
# xy =   [0.01587522 6.85062176]
# grad= [0.21751026 0.00025202]
#
# ****************** Iteration 42 ********************
# xy =   [0.01370012 6.85061924]
# grad= [1.87708576e-01 1.87693218e-04]
#
# ****************** Iteration 43 ********************
# xy =   [0.01182303 6.85061737]
# grad= [1.61990132e-01 1.39784078e-04]
#
# ****************** Iteration 44 ********************
# xy =   [0.01020313 6.85061597]
# grad= [1.39795455e-01 1.04103869e-04]
#
# ****************** Iteration 45 ********************
# xy =   [0.00880518 6.85061493]
# grad= [1.20641738e-01 7.75311209e-05]
#
# ****************** Iteration 46 ********************
# xy =   [0.00759876 6.85061415]
# grad= [1.04112324e-01 5.77411296e-05]
#
# ****************** Iteration 47 ********************
# xy =   [6.55763518e-03 6.85061358e+00]
# grad= [8.98476492e-02 4.30025792e-05]
#
# ****************** Iteration 48 ********************
# xy =   [5.65915869e-03 6.85061315e+00]
# grad= [7.75374138e-02 3.20260771e-05]
#
# ****************** Iteration 49 ********************
# xy =   [4.88378455e-03 6.85061283e+00]
# grad= [6.69138342e-02 2.38513516e-05]
#
# ****************** Iteration 50 ********************
# xy =   [4.21464621e-03 6.85061259e+00]
# grad= [5.77458168e-02 1.77632427e-05]
#
# ****************** Iteration 51 ********************
# xy =   [3.63718804e-03 6.85061241e+00]
# grad= [4.98339311e-02 1.32291369e-05]
#
# ****************** Iteration 52 ********************
# xy =   [3.13884873e-03 6.85061228e+00]
# grad= [4.30060713e-02 9.85237137e-06]
#
# ****************** Iteration 53 ********************
# xy =   [2.70878802e-03 6.85061218e+00]
# grad= [3.71137124e-02 7.33753253e-06]
#
# ****************** Iteration 54 ********************
# xy =   [2.3376509e-03 6.8506121e+00]
# grad= [3.20286790e-02 5.46461171e-06]
#
# ****************** Iteration 55 ********************
# xy =   [2.01736411e-03 6.85061205e+00]
# grad= [2.76403577e-02 4.06975793e-06]
#
# ****************** Iteration 56 ********************
# xy =   [1.74096053e-03 6.85061201e+00]
# grad= [2.38532902e-02 3.03094356e-06]
#
# ****************** Iteration 57 ********************
# xy =   [1.50242763e-03 6.85061198e+00]
# grad= [2.05850974e-02 2.25728877e-06]
#
# ****************** Iteration 58 ********************
# xy =   [1.29657665e-03 6.85061196e+00]
# grad= [1.77646870e-02 1.68111102e-06]
#
# ****************** Iteration 59 ********************
# xy =   [1.11892978e-03 6.85061194e+00]
# grad= [1.53307074e-02 1.25200386e-06]
#
# ****************** Iteration 60 ********************
# xy =   [9.65622707e-04 6.85061193e+00]
# grad= [1.32302129e-02 9.32427213e-07]
#
# ****************** Iteration 61 ********************
# xy =   [8.33320579e-04 6.85061192e+00]
# grad= [1.14175118e-02 6.94423187e-07]
#
# ****************** Iteration 62 ********************
# xy =   [7.19145461e-04 6.85061191e+00]
# grad= [9.85317292e-03 5.17170194e-07]
#
# ****************** Iteration 63 ********************
# xy =   [6.20613732e-04 6.85061191e+00]
# grad= [8.50316764e-03 3.85161404e-07]
#
# ****************** Iteration 64 ********************
# xy =   [5.35582055e-04 6.85061190e+00]
# grad= [7.33812961e-03 2.86848138e-07]
#
# ****************** Iteration 65 ********************
# xy =   [4.62200759e-04 6.85061190e+00]
# grad= [6.33271604e-03 2.13629542e-07]
#
# ****************** Iteration 66 ********************
# xy =   [3.98873599e-04 6.85061190e+00]
# grad= [5.46505644e-03 1.59100148e-07]
#
# ****************** Iteration 67 ********************
# xy =   [3.44223034e-04 6.85061190e+00]
# grad= [4.71627683e-03 1.18489497e-07]
#
# ****************** Iteration 68 ********************
# xy =   [2.97060266e-04 6.85061189e+00]
# grad= [4.07008919e-03 8.82448017e-08]
#
# ****************** Iteration 69 ********************
# xy =   [2.56359374e-04 6.85061189e+00]
# grad= [3.51243716e-03 6.57201288e-08]
#
# ****************** Iteration 70 ********************
# xy =   [2.21235003e-04 6.85061189e+00]
# grad= [3.03119028e-03 4.89449264e-08]
#
# ****************** Iteration 71 ********************
# xy =   [1.90923100e-04 6.85061189e+00]
# grad= [2.61588012e-03 3.64516301e-08]
#
# ****************** Iteration 72 ********************
# xy =   [1.64764299e-04 6.85061189e+00]
# grad= [2.25747253e-03 2.71472741e-08]
#
# ****************** Iteration 73 ********************
# xy =   [1.42189573e-04 6.85061189e+00]
# grad= [1.94817117e-03 2.02178748e-08]
#
# ****************** Iteration 74 ********************
# xy =   [1.22707862e-04 6.85061189e+00]
# grad= [1.68124787e-03 1.50572193e-08]
#
# ****************** Iteration 75 ********************
# xy =   [1.05895383e-04 6.85061189e+00]
# grad= [1.45089634e-03 1.12138322e-08]
#
# ****************** Iteration 76 ********************
# xy =   [9.13864196e-05 6.85061189e+00]
# grad= [1.25210579e-03 8.35147770e-09]
#
# ****************** Iteration 77 ********************
# xy =   [7.88653618e-05 6.85061189e+00]
# grad= [1.08055197e-03 6.21974529e-09]
#
# ****************** Iteration 78 ********************
# xy =   [6.80598421e-05 6.85061189e+00]
# grad= [9.32503127e-04 4.63214210e-09]
#
#
# ****************** Training Report ********************
# Found solution after 79 iterations.
# xy_min = [6.80598421e-05 6.85061189e+00]
# Gradient= [9.32503127e-04 4.63214210e-09]

# %%
# Third function
# Multi-variable Gradient descent with learning rate = 0.01,
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 79 iterations.
# xy_min = [6.80598421e-05 6.85061189e+00]
# Gradient = [9.32503127e-04 4.63214210e-09]

# %%
xy_min , grad , i = Newton_Multi( (10,10) , 400,  1, 0.001 , Df_5 , DDf_5)
# Out:
# ****************** Iteration 0 ********************
# xy =  [5. 5.]
# grad= [50. 25.]
#
# ****************** Iteration 1 ********************
# xy =  [2.5 2.5]
# grad= [12.5   6.25]
#
# ****************** Iteration 2 ********************
# xy =  [1.25 1.25]
# grad= [3.125  1.5625]
#
# ****************** Iteration 3 ********************
# xy =  [0.625 0.625]
# grad= [0.78125  0.390625]
#
# ****************** Iteration 4 ********************
# xy =  [0.3125 0.3125]
# grad= [0.1953125  0.09765625]
#
# ****************** Iteration 5 ********************
# xy =  [0.15625 0.15625]
# grad= [0.04882812 0.02441406]
#
# ****************** Iteration 6 ********************
# xy =  [0.078125 0.078125]
# grad= [0.01220703 0.00610352]
#
# ****************** Iteration 7 ********************
# xy =  [0.0390625 0.0390625]
# grad= [0.00305176 0.00152588]
#
# ****************** Iteration 8 ********************
# xy =  [0.01953125 0.01953125]
# grad= [0.00076294 0.00038147]
#
#
# ****************** Training Report ********************
# Found solution after 9 iterations.
# xy_min = [0.01953125 0.01953125]
# Gradient= [0.00076294 0.00038147]

# %%
# Third function
# Multi-variable Newton's method without learning rate, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 9 iterations.
# xy_min = [0.01953125 0.01953125]
# Gradient = [0.00076294 0.00038147]

# %% [markdown]
# ## BFGS
# - Implement the <b>BFGS</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐+xy+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐y$
# - The stop condition is grad < epsilon.
# - Try different epsilons and initial conditions.
# - Compare the results from Gradient descent and Newton's method.

# %%
## First function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[20.]
#  [20.]]
# Dfxn
#  [[18.]
#  [18.]]
# 25.45584412271571
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[0.]
#  [0.]]
# Dfxn_1
#  [[18.]
#  [18.]]
# Dfxn
#  [[0.]
#  [0.]]
# 0.0
# *****
# Found solution after 1 iterations.
# xy_min = [[0.]
#  [0.]]
# Gradient = [[0.]
#  [0.]]

# %%
## First function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001, 
## learning rate =0.9
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[20.]
#  [20.]]
# Dfxn
#  [[18.]
#  [18.]]
# 25.45584412271571
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[0.9]
#  [0.9]]
# Dfxn_1
#  [[18.]
#  [18.]]
# Dfxn
#  [[1.8]
#  [1.8]]
# 2.545584412271567
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[0.9]
#  [0.9]]
# xn
# : [[0.09]
#  [0.09]]
# Dfxn_1
#  [[1.8]
#  [1.8]]
# Dfxn
#  [[0.18]
#  [0.18]]
# 0.2545584412271567
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[0.09]
#  [0.09]]
# xn
# : [[0.009]
#  [0.009]]
# Dfxn_1
#  [[0.18]
#  [0.18]]
# Dfxn
#  [[0.018]
#  [0.018]]
# 0.025455844122715655
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[0.009]
#  [0.009]]
# xn
# : [[0.0009]
#  [0.0009]]
# Dfxn_1
#  [[0.018]
#  [0.018]]
# Dfxn
#  [[0.0018]
#  [0.0018]]
# 0.0025455844122715655
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[0.0009]
#  [0.0009]]
# xn
# : [[9.e-05]
#  [9.e-05]]
# Dfxn_1
#  [[0.0018]
#  [0.0018]]
# Dfxn
#  [[0.00018]
#  [0.00018]]
# 0.00025455844122715653
# *****
# Found solution after 5 iterations.
# xy_min = [[9.e-05]
#  [9.e-05]]
# Gradient = [[0.00018]
#  [0.00018]]

# %%
## Second function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[30.]
#  [30.]]
# Dfxn
#  [[27.]
#  [27.]]
# 38.18376618407357
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[1.77635684e-15]
#  [1.77635684e-15]]
# Dfxn_1
#  [[27.]
#  [27.]]
# Dfxn
#  [[5.32907052e-15]
#  [5.32907052e-15]]
# 7.53644380168212e-15
# *****
# Found solution after 1 iterations.
# xy_min = [[1.77635684e-15]
#  [1.77635684e-15]]
# Gradient = [[5.32907052e-15]
#  [5.32907052e-15]]

# %%
## Second function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001,
## learning rate  = 0.9
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[30.]
#  [30.]]
# Dfxn
#  [[27.]
#  [27.]]
# 38.18376618407357
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[0.9]
#  [0.9]]
# Dfxn_1
#  [[27.]
#  [27.]]
# Dfxn
#  [[2.7]
#  [2.7]]
# 3.8183766184073655
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[0.9]
#  [0.9]]
# xn
# : [[0.09]
#  [0.09]]
# Dfxn_1
#  [[2.7]
#  [2.7]]
# Dfxn
#  [[0.27]
#  [0.27]]
# 0.38183766184073553
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[0.09]
#  [0.09]]
# xn
# : [[0.009]
#  [0.009]]
# Dfxn_1
#  [[0.27]
#  [0.27]]
# Dfxn
#  [[0.027]
#  [0.027]]
# 0.038183766184073605
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[0.009]
#  [0.009]]
# xn
# : [[0.0009]
#  [0.0009]]
# Dfxn_1
#  [[0.027]
#  [0.027]]
# Dfxn
#  [[0.0027]
#  [0.0027]]
# 0.0038183766184073705
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[0.0009]
#  [0.0009]]
# xn
# : [[9.e-05]
#  [9.e-05]]
# Dfxn_1
#  [[0.0027]
#  [0.0027]]
# Dfxn
#  [[0.00027]
#  [0.00027]]
# 0.0003818376618407376
# *****
# Found solution after 5 iterations.
# xy_min = [[9.e-05]
#  [9.e-05]]
# Gradient = [[0.00027]
#  [0.00027]]

# %%
## Third function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[200.]
#  [100.]]
# Dfxn
#  [[162.]
#  [ 81.]]
# 181.12150617748296
# *****
# B_inv
#  [[ 0.23976608 -0.42690058]
#  [-0.42690058  0.90643275]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[4.73684211]
#  [4.73684211]]
# Dfxn_1
#  [[162.]
#  [ 81.]]
# Dfxn
#  [[44.87534626]
#  [22.43767313]]
# 50.172162376034116
# *****
# B_inv
#  [[ 0.24648787 -0.4201788 ]
#  [-0.4201788   0.91315453]]
# ****************
# xn_1:
#  [[4.73684211]
#  [4.73684211]]
# xn
# : [[3.10344828]
#  [3.10344828]]
# Dfxn_1
#  [[44.87534626]
#  [22.43767313]]
# Dfxn
#  [[19.2627824]
#  [ 9.6313912]]
# 21.536445443220412
# *****
# B_inv
#  [[ 0.26473765 -0.40192901]
#  [-0.40192901  0.93140432]]
# ****************
# xn_1:
#  [[3.10344828]
#  [3.10344828]]
# xn
# : [[1.875]
#  [1.875]]
# Dfxn_1
#  [[19.2627824]
#  [ 9.6313912]]
# Dfxn
#  [[7.03125 ]
#  [3.515625]]
# 7.861176483398041
# *****
# B_inv
#  [[ 0.28917749 -0.37748918]
#  [-0.37748918  0.95584416]]
# ****************
# xn_1:
#  [[1.875]
#  [1.875]]
# xn
# : [[1.16883117]
#  [1.16883117]]
# Dfxn_1
#  [[7.03125 ]
#  [3.515625]]
# Dfxn
#  [[2.7323326]
#  [1.3661663]]
# 3.0548407181235913
# *****
# B_inv
#  [[ 0.33173333 -0.33493333]
#  [-0.33493333  0.9984    ]]
# ****************
# xn_1:
#  [[1.16883117]
#  [1.16883117]]
# xn
# : [[0.72]
#  [0.72]]
# Dfxn_1
#  [[2.7323326]
#  [1.3661663]]
# Dfxn
#  [[1.0368]
#  [0.5184]]
# 1.1591776395384108
# *****
# B_inv
#  [[ 0.3986982  -0.26796846]
#  [-0.26796846  1.06536487]]
# ****************
# xn_1:
#  [[0.72]
#  [0.72]]
# xn
# : [[0.44554455]
#  [0.44554455]]
# Dfxn_1
#  [[1.0368]
#  [0.5184]]
# Dfxn
#  [[0.3970199 ]
#  [0.19850995]]
# 0.4438817424253175
# *****
# B_inv
#  [[ 0.50821158 -0.15845509]
#  [-0.15845509  1.17487824]]
# ****************
# xn_1:
#  [[0.44554455]
#  [0.44554455]]
# xn
# : [[0.27522936]
#  [0.27522936]]
# Dfxn_1
#  [[0.3970199 ]
#  [0.19850995]]
# Dfxn
#  [[0.1515024]
#  [0.0757512]]
# 0.16938483122775097
# *****
# B_inv
#  [[0.68468809 0.01802142]
#  [0.01802142 1.35135476]]
# ****************
# xn_1:
#  [[0.27522936]
#  [0.27522936]]
# xn
# : [[0.17013233]
#  [0.17013233]]
# Dfxn_1
#  [[0.1515024]
#  [0.0757512]]
# Dfxn
#  [[0.05789002]
#  [0.02894501]]
# 0.06472300563340837
# *****
# B_inv
#  [[0.97067757 0.3040109 ]
#  [0.3040109  1.63734424]]
# ****************
# xn_1:
#  [[0.17013233]
#  [0.17013233]]
# xn
# : [[0.10514019]
#  [0.10514019]]
# Dfxn_1
#  [[0.05789002]
#  [0.02894501]]
# Dfxn
#  [[0.02210892]
#  [0.01105446]]
# 0.024718521571080263
# *****
# B_inv
#  [[1.43314347 0.7664768 ]
#  [0.7664768  2.09981013]]
# ****************
# xn_1:
#  [[0.10514019]
#  [0.10514019]]
# xn
# : [[0.06498195]
#  [0.06498195]]
# Dfxn_1
#  [[0.02210892]
#  [0.01105446]]
# Dfxn
#  [[0.00844531]
#  [0.00422265]]
# 0.009442140847276249
# *****
# B_inv
#  [[2.18159883 1.51493216]
#  [1.51493216 2.84826549]]
# ****************
# xn_1:
#  [[0.06498195]
#  [0.06498195]]
# xn
# : [[0.04016064]
#  [0.04016064]]
# Dfxn_1
#  [[0.00844531]
#  [0.00422265]]
# Dfxn
#  [[0.00322575]
#  [0.00161288]]
# 0.00360650308820827
# *****
# B_inv
#  [[3.39252008 2.7258534 ]
#  [2.7258534  4.05918673]]
# ****************
# xn_1:
#  [[0.04016064]
#  [0.04016064]]
# xn
# : [[0.02482074]
#  [0.02482074]]
# Dfxn_1
#  [[0.00322575]
#  [0.00161288]]
# Dfxn
#  [[0.00123214]
#  [0.00061607]]
# 0.0013775723661749758
# *****
# B_inv
#  [[5.35189668 4.68523   ]
#  [4.68523    6.01856332]]
# ****************
# xn_1:
#  [[0.02482074]
#  [0.02482074]]
# xn
# : [[0.01534004]
#  [0.01534004]]
# Dfxn_1
#  [[0.00123214]
#  [0.00061607]]
# Dfxn
#  [[0.00047063]
#  [0.00023532]]
# 0.0005261842519803843
# *****
# Found solution after 13 iterations.
# xy_min = [[0.01534004]
#  [0.01534004]]
# Gradient = [[0.00047063]
#  [0.00023532]]
